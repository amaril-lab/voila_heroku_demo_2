# %%
import pandas as pd
import dash
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_html_components as html
import numpy as np

from base64 import b64encode
import io
#import dash_uploader as du

#import plotly.graph_objs as go

#import dash_core_components as dcc



#import dash_core_components as dcc
# Out:
# C:\Users\Haim\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
df0 = pd.read_csv('cleandf.spatial_data.csv')
print (df0.columns)
df0= df0[['Dose_number', 'Count', 'city_desc','Religion_Desc', 'arab_rate',
     'ortodox_rate', 'relevant_desk', 'perc', 'count_nonvac_young', 'count_age_old', 'diff', 'skewfirst',
       'skewsecond', 'kurfirst', 'kursecond', 'meanfirst', 'stdfirst',
       'meanthird', 'stdthird', 'meanlast', 'stdlast', 'meanrisk1', 'stdrisk1',
       'meanrisk3', 'stdrisk2', 'meanimmunity', 'stdimmunity', 'hosp_total',
       'recovered_total', 'death_total', 'positive_total', 'recavored_norm', 'hosp_norm', 'positive_norm',
       'death_norm', 'anomaly']]
print(df0.columns)
# Out:
# Index(['city_code', 'Dose_number', 'Count', 'agas_code',
#        'patient_agas_area_code', 'address_X', 'address_Y', 'neighborhood_name',
#        'city_latitude', 'city_longitude', 'CityPopulation', 'city_desc',
#        'Religion_Desc', 'arab_rate', 'ortodox_rate', 'relevant_desk', 'perc',
#        'count_nonvac_young', 'count_age_old', 'diff', 'skewfirst',
#        'skewsecond', 'kurfirst', 'kursecond', 'meanfirst', 'stdfirst',
#        'meanthird', 'stdthird', 'meanlast', 'stdlast', 'meanrisk1', 'stdrisk1',
#        'meanrisk3', 'stdrisk2', 'meanimmunity', 'stdimmunity', 'hosp_total',
#        'recovered_total', 'death_total', 'positive_total', 'recavored_norm',
#        'hosp_norm', 'positive_norm', 'death_norm', 'anomaly'],
#       dtype='object')
# Index(['Dose_number', 'Count', 'city_desc', 'Religion_Desc', 'arab_rate',
#        'ortodox_rate', 'relevant_desk', 'perc', 'count_nonvac_young',
#        'count_age_old', 'diff', 'skewfirst', 'skewsecond', 'kurfirst',
#        'kursecond', 'meanfirst', 'stdfirst', 'meanthird', 'stdthird',
#        'meanlast', 'stdlast', 'meanrisk1', 'stdrisk1', 'meanrisk3', 'stdrisk2',
#        'meanimmunity', 'stdimmunity', 'hosp_total', 'recovered_total',
#        'death_total', 'positive_total', 'recavored_norm', 'hosp_norm',
#        'positive_norm', 'death_norm', 'anomaly'],
#       dtype='object')

# %%
df = pd.read_csv('AgglomerativeClustering_n10_knn_011220_081221.csv')
del df["id_num"]
del df["city_from"]
del df["connected_component"]
del df["an"]
df = df.merge(df0, left_on='city_name', right_on='city_desc')
del df["city_desc"]
df.head()
df["perc"] = df["perc"]*100 
df["hosp_norm"] = df["hosp_norm"]*100 
df["positive_norm"] = df["positive_norm"]*100 
df["death_norm"] = df["death_norm"]*100 
df["meanimmunity"] = df["meanimmunity"]*100 
df["stdimmunity"] = df["stdimmunity"]*100 
df["diff"] = df["diff"]*100 
df["count_age_old"] = df["count_age_old"]*100 
df["count_nonvac_young"] = df["count_nonvac_young"]*100 
df['meanimmunity'] =  df['meanimmunity'].fillna(0)
df['size'] =  0.1
df["clusters"] = df["clusters"].astype(str)

df1 = pd.melt(df, id_vars=['city_name',"city_longitude","city_latitude", "size", "relevant_desk"], value_vars=["clusters",'perc', 'count_nonvac_young',
       'count_age_old', 'diff','meanfirst', 'meanthird', 'meanlast', 'meanrisk1', 'meanrisk3'
        ,"meanimmunity",'stdimmunity', 'hosp_total', 'death_total', 'positive_total',  'hosp_norm',
       'positive_norm', 'death_norm'])

# %%
df1.head()
# Out:
#             city_name  city_longitude  city_latitude  size relevant_desk  \
# 0  אבו ג'ווייעד (שבט)        34.92300       30.98600   0.1       חסר דסק
# 1             אבו גוש        35.10919       31.80629   0.1      דסק ערבי
# 2            אבו סנאן        35.17197       32.95803   0.1      דסק ערבי
# 3     אבו עבדון (שבט)        34.92300       30.98600   0.1           non
# 4      אבו עמאר (שבט)        34.92300       30.98600   0.1           non
#
#    variable value
# 0  clusters     5
# 1  clusters     3
# 2  clusters     5
# 3  clusters     1
# 4  clusters     8

# %%
#lst_col =['perc', 'count_nonvac_young','count_age_old', 'diff', 'meanimmunity', 'stdimmunity',  'hosp_norm','positive_norm', 'death_norm']
#dfsub = df[ (df["city_name"] == "אבו גוש") & (df["variable"].isin(lst_col0))]
#print (dfsub)
#fig = px.bar(dfsub, x="variable", y="value", color="city_name", title="")
#fig.show()
#lst_col0 = ['meanfirst', 'meanthird', 'meanlast', 'meanrisk1', 'meanrisk3','hosp_total', 'death_total', 'positive_total']
#dfsub = df1[ (df1["city_name"] == "אבו גוש") & (df1["variable"].isin(lst_col0))]
#print (dfsub)
#fig = px.bar(dfsub, x="variable", y="value", color="city_name", title="")
#fig.update_layout(showlegend=False,width=700,height=300)
#fig.show()
#available_indicators = df1['variable'].unique()

#V = available_indicators[1]
#mask = df1[ (df1["variable"] == V)]
#mask["value"] = mask["value"].astype(float)
#fig = px.scatter_mapbox(mask, lat="city_latitude", lon="city_longitude",
#            color="value", size = "size",zoom=5, text="city_name",mapbox_style="open-street-map", 
#            title = '')
#fig

# %%
#buffer = io.StringIO()
#html_bytes = buffer.getvalue().encode()
#encoded = b64encode(html_bytes).decode()

cities = df1.city_name.unique()
#opclass = df1.clusters.unique()
available_indicators = df1['variable'].unique()
lst_col0 = ['meanfirst', 'meanthird', 'meanlast', 'meanrisk1', 'meanrisk3','hosp_total', 'death_total', 'positive_total']
lst_col =['perc', 'count_nonvac_young','count_age_old', 'diff', 'meanimmunity', 'stdimmunity',  'hosp_norm','positive_norm', 'death_norm']



external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

app.config.suppress_callback_exceptions = True

#du.configure_upload(app, r"C:\Users\Haim\Desktop\covid")

# Create server variable with Flask server object for use with gunicorn
server = app.server
app.layout = html.Div([
    
    html.Div([
        dcc.Dropdown(
        id="dropdown_indicators",
        options=[{'label': i, 'value': i} for i in available_indicators],
        value=available_indicators[0],
        clearable=False,
        style=dict(
                    width='70%',
                    verticalAlign="middle")
        ), 
        
        dcc.Graph(id="MapPlot"),
        #html.A(
        #html.Button("Download HTML"), 
        #id="download",
        #href="data:text/html;base64," +encoded,
        #download="plotly_graph.html"
    #)
    ], className="one-third column",
    style={'width': '50%' ,'display': 'inline-block','padding': '0 20'}
    ),  
    
    html.Div([
        dcc.Dropdown(
        id="dropdown_city",
        options=[{"label": x, "value": x} for x in cities],
        value=cities[0],
        clearable=False,
        ),
        dcc.Graph(id="x-bar-chart"),
        dcc.Graph(id="y-bar-chart"),
        #      dcc.Graph(id="tbl", )
    
    ],
    className="one-third column",
    style={'width': '40%', 'display': 'inline-block' }
    )
    
    ])


@app.callback(
    Output("MapPlot", "figure"),
    [Input("dropdown_indicators", "value")])
def update_scatter_mapbox(V):
    mask = df1[ (df1["variable"] == V)]
    if V != "clusters":
        mask["value"] = mask["value"].astype(float)  
    fig = px.scatter_mapbox(mask, lat="city_latitude", lon="city_longitude",
            color="value",zoom=5, text="city_name",mapbox_style="open-street-map")
    #fig.write_html(buffer)
    fig.update_layout(showlegend=False,width=500,height=700)  
    return fig

@app.callback(
    Output("x-bar-chart", "figure"), 
    [Input("dropdown_city", "value")])
def update_bar_chart(city):
    mask = df1[ (df1["city_name"] == city) & (df1["variable"].isin(lst_col))]
    
    fig1 = px.bar(mask, x="variable", y="value", color="city_name")
    fig1.update_layout(showlegend=False,width=500,height=300)
    
    return fig1
@app.callback(
    Output("y-bar-chart", "figure"), 
    [Input("dropdown_city", "value")])
def update_bar_chart(city):
    mask = df1[ (df1["city_name"] == city) & (df1["variable"].isin(lst_col0))]
    
    fig2 = px.bar(mask, x="variable", y="value", color="city_name")
    fig2.update_layout(showlegend=False,width=500,height=300)
    
    return fig2

app.run_server(debug=False, port=2019, mode='external')#
# Out:
#  * Running on http://127.0.0.1:2019/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Jan/2022 09:09:26] "GET /_alive_c34958d2-e235-4ff8-8c53-28b5393991e6 HTTP/1.1" 200 -
# Dash app running on http://localhost:8888/proxy/2019/
# 127.0.0.1 - - [13/Jan/2022 09:09:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_0_0m1637482339.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_0_0m1637482339.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_0_0m1637482339.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_0_0m1637482339.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/deps/react@16.v2_0_0m1637482339.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_0_0m1637482339.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_0_0m1637482339.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/dash_table/bundle.v5_0_0m1637482339.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:29] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_0m1637482339.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:31] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:31] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:31] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:31] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:31] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 09:09:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:01:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:02:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2022 12:02:00] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
#app.run_server(mode="jupyterlab")

# %%
#@app.callback(
#    Output("tbl", "figure"), 
#    [Input("dropdown", "value")])
#def update_data_frame(city):
#    clascity = df.loc[df["city_name"] == city, "clusters"].values[0]
    
#    mask = df.loc[df["clusters"] == clascity, "city_name"]
#    dat = pd.DataFrame(mask)
    
#    return dat
